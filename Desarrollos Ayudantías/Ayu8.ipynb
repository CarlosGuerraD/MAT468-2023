# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
unif = np.random.default_rng().uniform
normal = np.random.default_rng().normal

# %%
def h(x):
    return np.sin(2 * np.pi * x)

K = 100
M = 1000

# %%
X = unif(0, 1, M)
X_sort = np.sort(X)

D_t = np.zeros((2,M))
for i in range(0, M):
    D_t[:,i] = (X_sort[i], h(X_sort[i]))
    
D_n = np.zeros((0,K))

tree_reg = DecisionTreeRegressor(max_depth=5)
tree_reg.fit(D_t[0,:].reshape(-1, 1), D_t[1,:].reshape(-1, 1))
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(tree_reg)
plt.show()

# %%
tree_reg.decision_path(D_t[0,:].reshape(-1,1))
# Out:
# <1000x63 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6000 stored elements in Compressed Sparse Row format>

# %%
tree_reg.predict(D_t[0,:].reshape(-1,1))
# Out:
# array([ 0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.06172339,
#         0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.06172339,
#         0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.06172339,
#         0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.06172339,
#         0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.06172339,
#         0.06172339,  0.06172339,  0.06172339,  0.06172339,  0.18956246,
#         0.18956246,  0.18956246,  0.18956246,  0.18956246,  0.18956246,
#         0.18956246,  0.18956246,  0.18956246,  0.18956246,  0.18956246,
#         0.18956246,  0.18956246,  0.18956246,  0.18956246,  0.18956246,
#         0.18956246,  0.18956246,  0.18956246,  0.18956246,  0.18956246,
#         0.18956246,  0.36416611,  0.36416611,  0.36416611,  0.36416611,
#         0.36416611,  0.36416611,  0.36416611,  0.36416611,  0.36416611,
#         0.36416611,  0.36416611,  0.36416611,  0.36416611,  0.36416611,
# ...
